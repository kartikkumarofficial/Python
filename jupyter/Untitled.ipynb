# %%
import sys
print(sys.executable)
# Out:
# C:\ProgramData\anaconda3\python.exe

# %%
# !where jupyter
# Out:
# INFO: Could not find files for the given pattern(s).

# %%
# !where python
# Out:
# C:\Users\Kartik\AppData\Local\Programs\Python\Python312\python.exe
# C:\Users\Kartik\AppData\Local\Microsoft\WindowsApps\python.exe

# %%
import matplotlib as plt

# %%
import numpy as np

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Kartik\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (C:\Users\Kartik\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Kartik\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (C:\Users\Kartik\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Kartik\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (C:\Users\Kartik\AppData\Roaming\Python\Python312\site-packages)
