# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("animals.csv")

# %%
df.shape
# Out:
# (20, 9)

# %%
df
# Out:
#     Is_Mammal  Can_Fly  Lives_In_Water  Has_Fur  Has_Feathers  Is_Domestic  \
# 0           1        0               0        1             0            1
# 1           1        0               0        1             0            1
# 2           1        0               0        1             0            0
# 3           1        0               0        1             0            0
# 4           1        0               0        0             0            0
# 5           1        0               0        1             0            0
# 6           1        0               0        1             0            1
# 7           0        1               0        0             1            0
# 8           0        1               0        0             1            0
# 9           0        0               1        0             0            0
# 10          0        0               1        0             0            0
# 11          0        0               0        0             0            0
# 12          0        0               0        0             0            1
# 13          0        0               1        0             0            0
# 14          0        0               0        0             1            0
# 15          0        1               0        0             1            0
# 16          1        0               0        1             0            0
# 17          1        0               1        0             0            0
# 18          0        0               1        0             0            0
# 19          0        0               0        0             0            0
#
#     Is_Dangerous  Has_Legs     Animal
# 0              0         1        Dog
# 1              0         1        Cat
# 2              1         1       Lion
# 3              1         1      Tiger
# 4              1         1   Elephant
# 5              0         1        Cow
# 6              0         1      Horse
# 7              0         1      Eagle
# 8              0         1     Parrot
# 9              1         0      Shark
# 10             0         0       Fish
# 11             1         0      Snake
# 12             0         1     Lizard
# 13             0         1       Frog
# 14             0         1    Chicken
# 15             0         1        Owl
# 16             0         1     Monkey
# 17             1         1    Dolphin
# 18             1         1  Crocodile
# 19             1         1       Wolf

# %%
X=df.drop('Animal',axis=1)
y=df['Animal']

# %%
model = DecisionTreeClassifier(
    criterion = 'gini',
    max_depth=5,
    random_state=42
)

# %%
model.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=42)

# %%
y_pred = model.predict(X)

# %%
accuracy_score(y,y_pred)
# Out:
# 0.55

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(15,8))
plot_tree(model,feature_names = X.columns,class_names = model.classes_ , filled=True)
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model2 = RandomForestClassifier(
    n_estimators=100,
    max_depth=5,
    random_state=42
)

# %%
model2.fit(X,y)
# Out:
# RandomForestClassifier(max_depth=5, random_state=42)

# %%
y_pred=model2.predict(X)
