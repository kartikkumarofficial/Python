# %%
# working with csv files

# %%
# local files
import pandas as pd
df = pd.read_csv("C:/files/programming/Python/2025/jupyter/wine.csv")
df
# Out:
#    Unnamed: 0  id     name  age
# 0           0   1    Alice   25
# 1           1   2      Bob   30
# 2           2   3  Charlie   28

# %%
# from url
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/laxmimerit/All-CSV-ML-Data-Files-Download/master/Restaurant%20-%20Foods.csv"

req = requests.get(url)
data = StringIO(req.text)

df = pd.read_csv(data)
df.head()
# Out:
#    Food ID   Food Item  Price
# 0        1       Sushi   3.99
# 1        2     Burrito   9.99
# 2        3        Taco   2.99
# 3        4  Quesadilla   4.25
# 4        5       Pizza   2.49

# %% [markdown]
# # SQL

# %%
# !pip install mysql.connector

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host='localhost',user='root',password='',database='world')

# %%
sql=pd.read_sql_query("SELECT * FROM city where CountryCode='AFG' ",conn)
sql
# Out:
# C:\Users\Kartik\AppData\Local\Temp\ipykernel_17232\566420948.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql=pd.read_sql_query("SELECT * FROM city where CountryCode='AFG' ",conn)
#    ID            Name CountryCode  District  Population
# 0   1           Kabul         AFG     Kabol     1780000
# 1   2        Qandahar         AFG  Qandahar      237500
# 2   3           Herat         AFG     Herat      186800
# 3   4  Mazar-e-Sharif         AFG     Balkh      127800

# %% [markdown]
# # API

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=ec399ba5a8d948a40a84c1512501aac9&include_adult=false&include_video=false&language=en-US&page=1&sort_by=popularity.desc')

# %%
# response.json()['results']
df=pd.DataFrame(response.json()['results'])[['id','title','overview']]

# %%
df.head()
# Out:
#         id                          title  \
# 0    83533           Avatar: Fire and Ash
# 1   982843                The Great Flood
# 2   425274  Now You See Me: Now You Don't
# 3  1223601          Sisu: Road to Revenge
# 4  1084242                     Zootopia 2
#
#                                             overview
# 0  In the wake of the devastating war against the...
# 1  When a raging flood traps a researcher and her...
# 2  The original Four Horsemen reunite with a new ...
# 3  Returning to the house where his family was br...
# 4  After cracking the biggest case in Zootopia's ...

# %%
# this was for a single page
# now for multiple pages we'll form a loop
# we'll:
# 1-make a new df
# 2=append it in the main df

# %%
for i in range (1,500):
    response = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=ec399ba5a8d948a40a84c1512501aac9&include_adult=false&include_video=false&language=en-US&page={}&sort_by=popularity.desc'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview']]
    df=df.append(temp_df,ignore_index=True)
# this wont work rn - use some proper url
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17232\727966436.py in ?()
#       1 for i in range (1,500):
#       2     response = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=ec399ba5a8d948a40a84c1512501aac9&include_adult=false&include_video=false&language=en-US&page={}&sort_by=popularity.desc'.format(i))
#       3     temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview']]
# ----> 4     df=df.append(temp_df,ignore_index=True)
#       5
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# ...
