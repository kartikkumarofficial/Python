# %%
from sklearn.datasets import make_classification
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

# %%
X,y = make_classification(n_samples=400,n_features=5)

# %%
plt.figure(figsize=(8, 6))

plt.scatter(
    X[:, 0],
    X[:, 1],
    c=y,
s=50,
    alpha=0.7
)

plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Feature 1 vs Feature 2")
plt.grid(True)
plt.show()

# %%
df=pd.DataFrame(X,columns=["f1","f2","f3","f4","f5"])

# %%
df['target']=y

# %%
df.head()
# Out:
#          f1        f2        f3        f4        f5  target
# 0 -0.309582 -1.677684  0.313349  0.744837 -1.259293       0
# 1 -1.214021  0.077933  1.053973  0.667133  1.536799       0
# 2  0.330977 -0.150548 -0.283948 -0.512617 -0.544745       0
# 3  1.645803  3.323628 -1.518890  0.260148  1.252220       1
# 4  0.249706  0.243874 -0.223612  1.141302 -0.063293       0

# %%
X=df.drop('target',axis=1)
y=df['target']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
print(X.shape,y.shape)
# Out:
# (400, 5) (400,)

# %%
plt.scatter(X.iloc[:,0:1],y)

# %%
scaler = StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train_scaled,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred=knn.predict(X_test_scaled)

# %%
print("Acuuracy:", accuracy_score(y_test,y_pred))
# Out:
# Acuuracy: 0.8375
