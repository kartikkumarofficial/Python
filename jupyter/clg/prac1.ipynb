# %%
import math

# %%
num = 10.7

print("Floor:", math.floor(num))
print("Ceil:", math.ceil(num))
print("Square Root:", math.sqrt(16))
print("Integer Square Root:", math.isqrt(17))
print("GCD of 24 and 36:", math.gcd(24, 36))
# Out:
# Floor: 10
# Ceil: 11
# Square Root: 4.0
# Integer Square Root: 4
# GCD of 24 and 36: 12

# %%
import numpy as np

# %%
arr = np.array([1, 2, 3, 4, 5])
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr.ndim
# Out:
# 1

# %%
arr.shape
# Out:
# (5,)

# %%
arr.size
# Out:
# 5

# %%
arr.sum()
# Out:
# np.int64(15)

# %%
arr.mean()
# Out:
# np.float64(3.0)

# %%
arr.sort()
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
print(arr[arr>3])
# Out:
# [4 5]
