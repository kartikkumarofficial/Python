# %%
# Churn model is a predictive model that tells whether a user is likely to stop using the services or not

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler , LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
df = pd.read_csv('netflix_customer_churn.csv')
df.sample(7)
# Out:
#                                customer_id  age  gender subscription_type  \
# 1919  1accc892-44fa-4be9-bfc4-c9168ec4417a   28    Male          Standard
# 4891  e096d116-d8cc-473d-aca9-e8f785e96471   59   Other             Basic
# 2937  0ca91c24-0ea5-4885-8ae4-665754c4a464   25   Other           Premium
# 3473  1e5ea5bb-78d0-44d0-8ed9-1ab9ee0f5ec6   40    Male             Basic
# 2026  7954dfc1-63a1-4207-b3e0-4d55b73f564f   20    Male             Basic
# 3542  a47b3283-a619-43f4-8ae0-b649ee493a8e   68  Female           Premium
# 2029  3fe822d8-7078-4018-a420-b4496d29ccf2   33   Other             Basic
#
#       watch_hours  last_login_days         region  device  monthly_fee  \
# 1919         1.17               34           Asia  Laptop        13.99
# 4891         2.58               54        Oceania  Laptop         8.99
# 2937         2.51               18           Asia      TV        17.99
# 3473        23.44               40  North America      TV         8.99
# 2026         8.91               28         Africa      TV         8.99
# 3542         5.94               23        Oceania  Mobile        17.99
# 2029        24.50               46         Africa      TV         8.99
#
#       churned payment_method  number_of_profiles  avg_watch_time_per_day  \
# 1919        1         PayPal                   4                    0.03
# 4891        1    Credit Card                   4                    0.05
# 2937        0         PayPal                   5                    0.13
# 3473        0      Gift Card                   4                    0.57
# 2026        1         Crypto                   2                    0.31
# 3542        0      Gift Card                   5                    0.25
# 2029        0    Credit Card                   3                    0.52
#
#      favorite_genre
# 1919         Comedy
# 4891        Romance
# 2937         Sci-Fi
# 3473         Horror
# 2026         Comedy
# 3542         Horror
# 2029         Sci-Fi

# %%
df['customer_id'].nunique()
# Out:
# 5000
